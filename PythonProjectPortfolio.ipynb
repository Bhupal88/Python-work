# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhupal88/Python-work/blob/main/PythonProjectPortfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit of measurement converter

# %%
convert_from=input("Enter starting unit of measurement(inches, feet or yard): ")

convert_to=input("Enter starting unit of measurement to convert to(inches, feet or yard): ")

number_of_inches=input("Enter starting measurement in inches")

number_of_feet=input("Enter starting measurement in feet")

number_of_yard=input("Enter starting measurement in yard")
# Out:
# Enter starting unit of measurement(inches, feet or yard):  feet
# Enter starting unit of measurement to convert to(inches, feet or yard):  yard
# Enter starting measurement in inches 4
# Enter starting measurement in feet 5
# Enter starting measurement in yard 6

# %%
convert_from=input("Enter starting unit of measurement(inches, feet or yards): ")

convert_to=input("Enter starting unit of measurement to convert to(inches, feet or yards): ")

if convert_from.lower() in ["inches","in","inch"]:
    number_of_inches=int(input("Enter starting measurement in inches"))
    if convert_to.lower() in ["feet","foot","ft"]:
        print("Result: " + str(number_of_inches) + " inches = " + str(round(number_of_inches/12,2)) + " Feet")
    elif convert_to.lower() in ["yards","yard","yds","yd"]:
        print("Result: " + str(number_of_inches) + " inches = " + str(round(number_of_inches/36,2)) + " Yards")
    else:
        print("Your input was incorrect")

elif convert_from.lower() in ["feet","foot","ft"]:
    number_of_feet=int(input("Enter starting measurement in feet"))
    if convert_to.lower() in ["inches","in","inch"]:
        print("Result: " + str(number_of_feet) + " Feet = " + str(round(number_of_feet*12)) + " Inches")
    elif convert_to.lower() in ["yards","yard","yds","yd"]:
        print("Result: " + str(number_of_feet) + " Feet = " + str(round(number_of_feet/3,2)) + " Yards")
    else:
        print("Your input was incorrect")

elif convert_from.lower() in ["yards","yard","yds","yd"]:
    number_of_yards=int(input("Enter starting measurement in yards"))
    if convert_to.lower() in ["inches","in","inch"]:
        print("Result: " + str(number_of_yards) + " Yards = " + str(round(number_of_yards*36)) + " Inches")
    elif convert_to.lower() in ["feet","foot","ft"]:
        print("Result: " + str(number_of_yards) + " inches = " + str(round(number_of_yards*3)) + " Feet")
    else:
        print("Your input was incorrect")

else:
    print("Please enter either feet, inches or yards")
# Out:
# Enter starting unit of measurement(inches, feet or yards):  feet
# Enter starting unit of measurement to convert to(inches, feet or yards):  yard
# Enter starting measurement in feet 5
# Result: 5 Feet = 1.67 Yards
